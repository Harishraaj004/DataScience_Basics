# %%
import pandas as pd

# %%
#Dataset must need to be saved in the system, pd.read_csv can read the file through the link
df = pd.read_csv("C:/Users/DELL/OneDrive/Desktop/weather dataset/weatherData.csv")
df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR               NaN
#
# ...

# %%
df['HourlyWindSpeed'].max()
# Out:
# 21.0

# %%
df['Month'][df['HourlySkyWeather']=='CLR'] #returns the month and HourlySkyWeather values where it was "CLR"
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 8753    9
# 8754    9
# 8755    9
# 8756    9
# 8757    9
# Name: Month, Length: 4229, dtype: int64

# %%
df['HourlyWindSpeed'].mean()
# Out:
# 4.849508599508599

# %%
df.fillna(0, inplace=True) #it fills the NaN value into 0
df['HourlyWindSpeed'].mean()
# Out:
# 4.5073076044759075

# %%
df.shape #returns the rows and columns
# Out:
# (8758, 13)

# %%
rows, columns = df.shape
rows
# Out:
# 8758

# %%
columns
# Out:
# 13

# %%
df.head(5) #returns the first 5 rows since it is specified
# Out:
#    Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0  2017      9   16     0          747              CLR               7.0
# 1  2017      9   16     1          747              CLR               6.0
# 2  2017      9   16     2          747              CLR               4.0
# 3  2017      9   16     3          747              CLR               3.0
# 4  2017      9   16     4          747              CLR               3.0
#
#   HourlyWindDirection  HourlyWindSpeed  SunriseHour  SunriseMin  SunsetHour  \
# 0                   0              0.0            5          37          18
# 1                   0              0.0            5          37          18
# 2                  40              3.0            5          37          18
# 3                  50              3.0            5          37          18
# 4                   0              0.0            5          37          18
#
#    SunsetMin
# 0          4
# 1          4
# 2          4
# ...

# %%
df.tail(5) #returns the last 5 rows since it is specified
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR               0.0
#
#      HourlyWindDirection  HourlyWindSpeed  SunriseHour  SunriseMin  \
# 8753               False              0.0            5          37
# 8754               False              0.0            5          37
# 8755               False              0.0            5          37
# 8756               False              0.0            5          37
# 8757               False              0.0            5          37
#
#       SunsetHour  SunsetMin
# 8753          18          4
# 8754          18          4
# ...

# %%
df[2:5] #slicing
# Out:
#    Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 2  2017      9   16     2          747              CLR               4.0
# 3  2017      9   16     3          747              CLR               3.0
# 4  2017      9   16     4          747              CLR               3.0
#
#   HourlyWindDirection  HourlyWindSpeed  SunriseHour  SunriseMin  SunsetHour  \
# 2                  40              3.0            5          37          18
# 3                  50              3.0            5          37          18
# 4                   0              0.0            5          37          18
#
#    SunsetMin
# 2          4
# 3          4
# 4          4

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'SunlightMin', 'HourlySkyWeather',
#        'HourlyVisibility', 'HourlyWindDirection', 'HourlyWindSpeed',
#        'SunriseHour', 'SunriseMin', 'SunsetHour', 'SunsetMin'],
#       dtype='object')

# %%
df['Month']
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 8753    9
# 8754    9
# 8755    9
# 8756    9
# 8757    9
# Name: Month, Length: 8758, dtype: int64

# %%
df.Month
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 8753    9
# 8754    9
# 8755    9
# 8756    9
# 8757    9
# Name: Month, Length: 8758, dtype: int64

# %%
type(df['Month']) 
#return the type of the column object, which is typically a pandas.Series
# Out:
# pandas.core.series.Series

# %%
df[['Year','SunriseHour']] #Returns the specified columns
# Out:
#       Year  SunriseHour
# 0     2017            5
# 1     2017            5
# 2     2017            5
# 3     2017            5
# 4     2017            5
# ...    ...          ...
# 8753  2018            5
# 8754  2018            5
# 8755  2018            5
# 8756  2018            5
# 8757  2018            5
#
# [8758 rows x 2 columns]

# %%
df.describe()
# Out:
#               Year        Month          Day         Hour  SunlightMin  \
# count  8758.000000  8758.000000  8758.000000  8758.000000  8758.000000
# mean   2017.706782     6.525462    15.720712    11.498630   732.412651
# std       0.455263     3.448239     8.797747     6.922774   120.662506
# min    2017.000000     1.000000     1.000000     0.000000   554.000000
# 25%    2017.000000     4.000000     8.000000     5.250000   616.000000
# 50%    2018.000000     7.000000    16.000000    11.000000   734.000000
# 75%    2018.000000    10.000000    23.000000    17.000000   849.000000
# max    2018.000000    12.000000    31.000000    23.000000   906.000000
#
#        HourlyVisibility  HourlyWindSpeed  SunriseHour   SunriseMin  \
# count       8758.000000      8758.000000  8758.000000  8758.000000
# mean           8.920130         4.507308     5.353505    28.469514
# std            2.335886         3.696661     1.082291    16.300217
# ...

# %%
df[df.HourlyWindSpeed==5] #Returns according to the condition
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 7     2017      9   16     7          747              OVC               2.0
# 8     2017      9   16     8          747              OVC               4.0
# 33    2017      9   17     9          744              BKN               4.0
# 34    2017      9   17    10          744              FEW               5.0
# 37    2017      9   17    13          744              SCT               7.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8602  2018      9    9    10          765              BKN               9.0
# 8615  2018      9    9    23          763              BKN               8.0
# 8616  2018      9   10     0          763              BKN               8.0
# 8623  2018      9   10     7          763              OVC               8.0
# 8627  2018      9   10    11          763              OVC               3.0
#
# ...

# %%
df[df.HourlyWindSpeed==df.HourlyWindSpeed.max()] #Returns the values from the dataset where the HourlyWindSpeed are maximum
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 2409  2017     12   25     9          556              CLR              10.0
# 2657  2018      1    4    17          562              OVC               9.0
# 3252  2018      1   29    12          601              FEW              10.0
# 4469  2018      3   21     5          731              BKN               4.0
#
#      HourlyWindDirection  HourlyWindSpeed  SunriseHour  SunriseMin  \
# 2409                 270             21.0            7          18
# 2657                 310             21.0            7          20
# 3252                  70             21.0            7           9
# 4469                  70             21.0            5          58
#
#       SunsetHour  SunsetMin
# 2409          16         34
# 2657          16         42
# 3252          17         10
# 4469          18          9

# %%
df[['Day']][df.HourlyWindSpeed==df.HourlyWindSpeed.max()] #Returns only the days where the HourlyWindSpeed is maximum
# Out:
#       Day
# 2409   25
# 2657    4
# 3252   29
# 4469   21

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8758, step=1)
